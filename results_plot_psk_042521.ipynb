# %% [markdown]
# # Plotting Results

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def get_line(sample_length, coverage, df):
    data = df[(df['sample_length'] == sample_length) & (df['coverage']==coverage)].drop(['sample_length', 'coverage'],axis=1)
    k_list = np.unique(data['k'].tolist())
    score_list = []
    for each in k_list:
        score = np.mean(data.loc[data['k'] == each, "score"].tolist())
        score_list.append(score)
    return np.unique(data['k'].tolist()), score_list

# %%
def get_line_C(sample_length, coverage, df):
    data = df[(df['sample_length'] == sample_length) & (df['coverage']==coverage)].drop(['sample_length', 'coverage'],axis=1)
    return data['C'].tolist(), data['score'].tolist()

# %%
filename='data/gridsearch-2000/results-2000-linearsvm-single.2021.04.20.15.31.csv'
df = pd.read_csv(filename)
df = df.drop(['experiment','classifier','training_shape', 'score_type', 'C'],axis=1)

test_k, test_cov = get_line(100, 1, df)

print(len(test_k))
print(len(test_cov))
# Out:
# 7
# 7

# %%
def plot_graphs(df, title, y_bot, y_top, y_ticks, legend_loc):


    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 5))

    # graph 1
    L=100
    line_L100_C0_1_k, line_L100_C0_1_score = get_line(L, 0.1, df)
    line_L100_C1_k, line_L100_C1_score = get_line(L, 1, df)
    line_L100_C10_k, line_L100_C10_score = get_line(L, 10, df)
    line_L100_C100_k, line_L100_C100_score = get_line(L, 100, df)
    line_L100_C200_k, line_L100_C200_score = get_line(L, 200, df)
    line_L100_C400_k, line_L100_C400_score = get_line(L, 400, df)

    ax1.plot(line_L100_C0_1_k, line_L100_C0_1_score, linestyle=':', label='cov=0.1',color='k')
    ax1.plot(line_L100_C1_k, line_L100_C1_score, linestyle='--', label='cov=1',color='k')
    ax1.plot(line_L100_C10_k, line_L100_C10_score, linestyle='-', label='cov=10',color='gray')
    ax1.plot(line_L100_C100_k, line_L100_C100_score, linestyle='--', label='cov=100',color='gray')
    ax1.plot(line_L100_C200_k, line_L100_C200_score, linestyle='-.', label='cov=200',color='k')
    ax1.plot(line_L100_C400_k, line_L100_C400_score, linestyle='-', label='cov=400',color='k')

    ax1.set_xticks([0, 1, 2,4,6,8,10,12])
    ax1.legend(loc=legend_loc)
    ax1.set_title('L=100')
    ax1.set_ylabel('average species-level recall')
    ax1.set_xlabel('k-mer size')
    ax1.grid(color='lightgray', linestyle=':', linewidth=1)
    ax1.set_ylim(y_bot, y_top)
    ax1.set_yticks(y_ticks)

    # graph 2
    L=200
    line_L200_C0_1_k, line_L200_C0_1_score = get_line(L, 0.1, df)
    line_L200_C1_k, line_L200_C1_score = get_line(L, 1, df)
    line_L200_C10_k, line_L200_C10_score = get_line(L, 10, df)
    line_L200_C100_k, line_L200_C100_score = get_line(L, 100, df)
    line_L200_C200_k, line_L200_C200_score = get_line(L, 200, df)
    line_L200_C400_k, line_L200_C400_score = get_line(L, 400, df)


    ax2.plot(line_L200_C0_1_k, line_L200_C0_1_score, linestyle=':', label='cov=0.1',color='k')
    ax2.plot(line_L200_C1_k, line_L200_C1_score, linestyle='--', label='cov=1',color='k')
    ax2.plot(line_L200_C10_k, line_L200_C10_score, linestyle='-', label='cov=10',color='gray')
    ax2.plot(line_L200_C100_k, line_L200_C100_score, linestyle='--', label='cov=100',color='gray')
    ax2.plot(line_L200_C200_k, line_L200_C200_score, linestyle='-.', label='cov=200',color='k')
    ax2.plot(line_L200_C400_k, line_L200_C400_score, linestyle='-', label='cov=400',color='k')

    ax2.set_xticks([0, 1, 2,4,6,8,10,12])
    ax2.legend(loc=legend_loc)
    ax2.set_title('L=200')
    ax2.set_ylabel('average species-level recall')
    ax2.set_xlabel('k-mer size')
    ax2.grid(color='lightgray', linestyle=':', linewidth=1)
    ax2.set_ylim(y_bot, y_top)
    ax2.set_yticks(y_ticks)

    # graph 3
    L=400
    line_L400_C0_1_k, line_L400_C0_1_score = get_line(L, 0.1, df)
    line_L400_C1_k, line_L400_C1_score = get_line(L, 1, df)
    line_L400_C10_k, line_L400_C10_score = get_line(L, 10, df)
    line_L400_C100_k, line_L400_C100_score = get_line(L, 100, df)
    line_L400_C200_k, line_L400_C200_score = get_line(L, 200, df)
    line_L400_C400_k, line_L400_C400_score = get_line(L, 400, df)


    ax3.plot(line_L400_C0_1_k, line_L400_C0_1_score, linestyle=':', label='cov=0.1',color='k')
    ax3.plot(line_L400_C1_k, line_L400_C1_score, linestyle='--', label='cov=1',color='k')
    ax3.plot(line_L400_C10_k, line_L400_C10_score, linestyle='-', label='cov=10',color='gray')
    ax3.plot(line_L400_C100_k, line_L400_C100_score, linestyle='--', label='cov=100',color='gray')
    ax3.plot(line_L400_C200_k, line_L400_C200_score, linestyle='-.', label='cov=200',color='k')
    ax3.plot(line_L400_C400_k, line_L400_C400_score, linestyle='-', label='cov=400',color='k')

    ax3.set_xticks([0, 1, 2,4,6,8,10,12])
    ax3.legend(loc=legend_loc)
    ax3.set_title('L=400')
    ax3.set_ylabel('average species-level recall')
    ax3.set_xlabel('k-mer size')
    ax3.grid(color='lightgray', linestyle=':', linewidth=1)
    ax3.set_ylim(y_bot, y_top)
    ax3.set_yticks(y_ticks)

    plt.suptitle(title, fontsize=16)
    plt.show()
    plt.savefig(title)

# %%
def plot_graphs_C(df, title, y_bot, y_top, y_ticks, legend_loc):


    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 5))

    # graph 1
    L=100
    line_L100_C0_1_k, line_L100_C0_1_score = get_line_C(L, 0.1, df)
    line_L100_C1_k, line_L100_C1_score = get_line_C(L, 1, df)
    line_L100_C10_k, line_L100_C10_score = get_line_C(L, 10, df)
    line_L100_C100_k, line_L100_C100_score = get_line_C(L, 100, df)
    line_L100_C200_k, line_L100_C200_score = get_line_C(L, 200, df)
    line_L100_C400_k, line_L100_C400_score = get_line_C(L, 400, df)

    ax1.plot(line_L100_C0_1_k, line_L100_C0_1_score, linestyle=':', label='cov=0.1',color='k')
    ax1.plot(line_L100_C1_k, line_L100_C1_score, linestyle='--', label='cov=1',color='k')
    ax1.plot(line_L100_C10_k, line_L100_C10_score, linestyle='-', label='cov=10',color='gray')
    ax1.plot(line_L100_C100_k, line_L100_C100_score, linestyle='--', label='cov=100',color='gray')
    ax1.plot(line_L100_C200_k, line_L100_C200_score, linestyle='-.', label='cov=200',color='k')
    ax1.plot(line_L100_C400_k, line_L100_C400_score, linestyle='-', label='cov=400',color='k')

    ax1.set_xticks([.01, .1, 1, 10, 100])
    ax1.set_xscale('log')
    ax1.legend(loc=legend_loc)
    ax1.set_title('L=100')
    ax1.set_ylabel('average species-level recall')
    ax1.set_xlabel('C value')
    ax1.grid(color='lightgray', linestyle=':', linewidth=1)
    ax1.set_ylim(y_bot, y_top)
    ax1.set_yticks(y_ticks)

    # graph 2
    L=200
    line_L200_C0_1_k, line_L200_C0_1_score = get_line_C(L, 0.1, df)
    line_L200_C1_k, line_L200_C1_score = get_line_C(L, 1, df)
    line_L200_C10_k, line_L200_C10_score = get_line_C(L, 10, df)
    line_L200_C100_k, line_L200_C100_score = get_line_C(L, 100, df)
    line_L200_C200_k, line_L200_C200_score = get_line_C(L, 200, df)
    line_L200_C400_k, line_L200_C400_score = get_line_C(L, 400, df)


    ax2.plot(line_L200_C0_1_k, line_L200_C0_1_score, linestyle=':', label='cov=0.1',color='k')
    ax2.plot(line_L200_C1_k, line_L200_C1_score, linestyle='--', label='cov=1',color='k')
    ax2.plot(line_L200_C10_k, line_L200_C10_score, linestyle='-', label='cov=10',color='gray')
    ax2.plot(line_L200_C100_k, line_L200_C100_score, linestyle='--', label='cov=100',color='gray')
    ax2.plot(line_L200_C200_k, line_L200_C200_score, linestyle='-.', label='cov=200',color='k')
    ax2.plot(line_L200_C400_k, line_L200_C400_score, linestyle='-', label='cov=400',color='k')

    ax2.set_xticks([.01, .1, 1, 10, 100])
    ax2.set_xscale('log')
    ax2.legend(loc=legend_loc)
    ax2.set_title('L=200')
    ax2.set_ylabel('average species-level recall')
    ax2.set_xlabel('C value')
    ax2.grid(color='lightgray', linestyle=':', linewidth=1)
    ax2.set_ylim(y_bot, y_top)
    ax2.set_yticks(y_ticks)

    # graph 3
    L=400
    line_L400_C0_1_k, line_L400_C0_1_score = get_line_C(L, 0.1, df)
    line_L400_C1_k, line_L400_C1_score = get_line_C(L, 1, df)
    line_L400_C10_k, line_L400_C10_score = get_line_C(L, 10, df)
    line_L400_C100_k, line_L400_C100_score = get_line_C(L, 100, df)
    line_L400_C200_k, line_L400_C200_score = get_line_C(L, 200, df)
    line_L400_C400_k, line_L400_C400_score = get_line_C(L, 400, df)


    ax3.plot(line_L400_C0_1_k, line_L400_C0_1_score, linestyle=':', label='cov=0.1',color='k')
    ax3.plot(line_L400_C1_k, line_L400_C1_score, linestyle='--', label='cov=1',color='k')
    ax3.plot(line_L400_C10_k, line_L400_C10_score, linestyle='-', label='cov=10',color='gray')
    ax3.plot(line_L400_C100_k, line_L400_C100_score, linestyle='--', label='cov=100',color='gray')
    ax3.plot(line_L400_C200_k, line_L400_C200_score, linestyle='-.', label='cov=200',color='k')
    ax3.plot(line_L400_C400_k, line_L400_C400_score, linestyle='-', label='cov=400',color='k')

    ax3.set_xticks([.01, .1, 1, 10, 100])
    ax3.set_xscale('log')
    ax3.legend(loc=legend_loc)
    ax3.set_title('L=400')
    ax3.set_ylabel('average species-level recall')
    ax3.set_xlabel('C value')
    ax3.grid(color='lightgray', linestyle=':', linewidth=1)
    ax3.set_ylim(y_bot, y_top)
    ax3.set_yticks(y_ticks)

    plt.suptitle(title, fontsize=16)
    plt.show()
    plt.savefig(title)

# %% [markdown]
# ## Plotting LinearSVM 2000 dataset

# %%
filename='data/gridsearch-2000/results-2000-linearsvm-single.2021.04.20.15.31.csv'
df = pd.read_csv(filename)
df = df.drop(['experiment','classifier','training_shape', 'score_type', 'C'],axis=1)


title = "LinearSVM Classifier 2000 Dataset (sklearn)"

plot_graphs(df, title, 0,1, np.linspace(0.1,1,10), 'lower right')

# %%
filename='data/gridsearch-2000/results-2000-linearsvm-5X.2021.04.20.16.15.csv'
df = pd.read_csv(filename)
df = df.drop(['experiment','classifier','training_shape', 'score_type','C'],axis=1)

means = df.groupby(['sample_length','coverage','k']).mean()

means = means.reset_index()

title = "LinearSVM Classifier 2000 Dataset 5X (sklearn)"

plot_graphs(means, title, 0,1, np.linspace(0.1,1,10), 'lower right')

# %%
filename='data/gridsearch-2000/results-2000-linearsvm-5X.2021.04.20.16.15.csv'
df = pd.read_csv(filename)
df = df.drop(['experiment','classifier','training_shape', 'score_type','k'],axis=1)

means = df.groupby(['sample_length','coverage','C']).mean()

means = means.reset_index()

title = "LinearSVM Classifier 2000 Dataset 5X C-values (sklearn)"

plot_graphs_C(means, title, 0,1, np.linspace(0.1,1,10), 'lower right')

# %% [markdown]
# ## Plotting LinearSVM 3000 Dataset

# %%
filename='data/gridsearch-3000/results-3000-linearsvm-single.2021.04.20.22.10.csv'
df = pd.read_csv(filename)
df = df.drop(['experiment','classifier','training_shape', 'score_type', 'C'],axis=1)

title = "LinearSVM Classifier 3000 Dataset (sklearn)"

plot_graphs(df, title, 0,1, np.linspace(0.1,1,10), 'lower right')

# %% [markdown]
# ## Plotting SVM Classifier 2000 Dataset

# %%
filename='data/gridsearch-2000/results-2000-svm-single.2021.04.21.12.48.csv'
df = pd.read_csv(filename)
df = df.drop(['experiment','classifier','training_shape', 'score_type', 'C'],axis=1)


title = "SVM Classifier 2000 Dataset (sklearn)"

plot_graphs(df, title, 0,1, np.linspace(0.1,1,10), 'lower right')

# %%
filename='data/gridsearch-2000/results-2000-svm-5X.2021.04.21.17.51.csv'
df = pd.read_csv(filename)
df = df.drop(['experiment','classifier','training_shape', 'score_type','C'],axis=1)

means = df.groupby(['sample_length','coverage','k']).mean()

means = means.reset_index()

title = "SVM Classifier 2000 Dataset 5X (sklearn)"

plot_graphs(means, title, 0,1, np.linspace(0.1,1,10), 'lower right')

# %%
filename='data/gridsearch-2000/results-2000-svm-5X.2021.04.21.17.51.csv'
df = pd.read_csv(filename)
df = df.drop(['experiment','classifier','training_shape', 'score_type','k'],axis=1)

means = df.groupby(['sample_length','coverage','C']).mean()

means = means.reset_index()

title = "SVM Classifier 2000 Dataset 5X C-values (sklearn)"

plot_graphs_C(means, title, 0,1, np.linspace(0.1,1,10), 'lower right')

# %% [markdown]
# ## Plotting SVM Classifier 3000 Dataset

# %%
filename='data/gridsearch-3000/results-3000-svm-single.2021.04.22.19.41.csv'
df = pd.read_csv(filename)
df = df.drop(['experiment','classifier','training_shape', 'score_type', 'C'],axis=1)

title = "SVM Classifier 3000 Dataset (sklearn)"

plot_graphs(df, title, 0,1, np.linspace(0.1,1,10), 'lower right')

# %% [markdown]
# ## Plotting Naive Bayes 2000 Dataset

# %%
filename='data/gridsearch-2000/results-2000-naivebayes-single.2021.04.19.14.11.csv'
df = pd.read_csv(filename)
df = df.drop(['experiment','classifier','training_shape', 'score_type'],axis=1)

title = "Naive Bayes Classifier 2000 Dataset"

plot_graphs(df, title, 0,1, np.linspace(0.1,1,10), 'lower right')

# %%
filename='data/gridsearch-2000/results-2000-naivebayes-5X.2021.04.19.14.35.csv'
df = pd.read_csv(filename)
df = df.drop(['experiment','classifier','training_shape', 'score_type'],axis=1)

means = df.groupby(['sample_length','coverage','k']).mean()

means = means.reset_index()

title = "Naive Bayes Classifier 2000 Dataset 5X"

plot_graphs(means, title, 0,1, np.linspace(0.1,1,10), 'lower right')

# %% [markdown]
# ## Naive Bayes Classifier 3000 Dataset

# %%
filename='data/gridsearch-3000/results-3000-naivebayes-single.2021.04.19.18.16.csv'
df = pd.read_csv(filename)
df = df.drop(['experiment','classifier','training_shape', 'score_type'],axis=1)

title = "Naive Bayes Classifier 3000 Dataset"

plot_graphs(df, title, 0,1, np.linspace(0.1,1,10), 'lower right')
